# %% [markdown]
# # Hypothesis 3
#
# Spain ¿ciudad de vacaciones?

# %% [markdown]
# ![enlace](https://media.giphy.com/media/FdhN24h2nN74X7lwZW/giphy.gif)

# %%
 #import pandas
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from math import nan, isnan

# %%
pds_shark = pd.read_csv("attacks.csv", encoding = "ISO-8859-1") #while downloading the document I encounter an error, which I look for on google and get they way of solving it
pds_shark
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
pds_shark.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
to_drop = ['Unnamed: 22','Unnamed: 23','href formula','href','Case Number','Case Number.2','Case Number.1','original order','pdf','Investigator or Source',
'Date','Year','Type','Age','Location','Activity','Name','Sex ','Area','Time', 'Species ']
pds_shark.drop(to_drop, inplace=True, axis=1)

# %%
pds_shark.columns
# Out:
# Index(['Country', 'Injury', 'Fatal (Y/N)'], dtype='object')

# %%
pds_shark.dropna(how = 'all', inplace = True)

# %%
pds_shark
# Out:
#                  Country                                             Injury  \
# 0                    USA  No injury to occupant, outrigger canoe and pad...
# 1                    USA                         Minor injury to left thigh
# 2                    USA       Injury to left lower leg from surfboard skeg
# 3              AUSTRALIA                          Minor injury to lower leg
# 4                 MEXICO  Lacerations to leg & hand shark PROVOKED INCIDENT
# ...                  ...                                                ...
# 6297           AUSTRALIA                                              FATAL
# 6298           AUSTRALIA                                              FATAL
# 6299                 USA                                              FATAL
# 6300              PANAMA                                              FATAL
# 6301  CEYLON (SRI LANKA)  FATAL. "Shark bit him in half, carrying away t...
#
#      Fatal (Y/N)
# 0              N
# 1              N
# ...

# %%
pds_shark['Country'].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', nan, 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS',
#        'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM',
#        'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA',
#        'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC',
#        'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'FIJI', 'PUERTO RICO',
#        'ITALY', 'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES',
#        'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA',
# ...

# %%
pds_shark.dropna(subset = ['Country'], inplace=True)

# %%
pds_shark[pds_shark['Country'].str.contains('SPAIN')]
# Out:
#      Country                                             Injury Fatal (Y/N)
# 82     SPAIN                          Lacerations to right foot           N
# 98     SPAIN                           Lacerations to left foot         NaN
# 113    SPAIN            Abrasion to arm from shark's rough skin           N
# 130    SPAIN                          2-inch laceration to hand           N
# 234    SPAIN                          Lacerations to right hand           N
# 249    SPAIN  5 tiny puncture marks to lower leg, treated wi...           N
# 321    SPAIN                        Lacerations to left forearm           N
# 378    SPAIN   Minor injury when he attempted to touch a fish.          NaN
# 471    SPAIN  Glancing bite to wrist from netted shark PROVO...           N
# 504    SPAIN                          Lacerations to right hand           N
# 509    SPAIN           Minor lacerations to posterior lower leg           N
# ...

# %%
pds_sharks = pds_shark[pds_shark['Country'] == 'SPAIN']
pds_sharks
# Out:
#      Country                                             Injury Fatal (Y/N)
# 82     SPAIN                          Lacerations to right foot           N
# 98     SPAIN                           Lacerations to left foot         NaN
# 113    SPAIN            Abrasion to arm from shark's rough skin           N
# 130    SPAIN                          2-inch laceration to hand           N
# 234    SPAIN                          Lacerations to right hand           N
# 249    SPAIN  5 tiny puncture marks to lower leg, treated wi...           N
# 321    SPAIN                        Lacerations to left forearm           N
# 378    SPAIN   Minor injury when he attempted to touch a fish.          NaN
# 471    SPAIN  Glancing bite to wrist from netted shark PROVO...           N
# 504    SPAIN                          Lacerations to right hand           N
# 509    SPAIN           Minor lacerations to posterior lower leg           N
# ...

# %%
pds_shark['Injury'].unique()
# Out:
# array(['No injury to occupant, outrigger canoe and paddle damaged',
#        'Minor injury to left thigh',
#        'Injury to left lower leg from surfboard skeg', ...,
#        'FATAL, leg stripped of flesh  ',
#        'FATAL, knocked overboard by tail of shark & carried off by shark ',
#        'FATAL. "Shark bit him in half, carrying away the lower extremities" '],
#       dtype=object)

# %%
contains_word = pds_sharks['Injury'].str.contains('PROVOKED')
contains_word
# Out:
# 82      False
# 98      False
# 113     False
# 130     False
# 234     False
# 249     False
# 321     False
# 378     False
# 471     False
# 504     False
# 509     False
# 529     False
# 657     False
# 1011    False
# 1107    False
# 1458    False
# 2476    False
# 2821    False
# 2822    False
# 3059    False
# 3409    False
# 3859    False
# 5038    False
# 5065    False
# 5149    False
# 5163    False
# 5187    False
# 5308    False
# 5379    False
# 5386    False
# 5421    False
# 5432    False
# 5433    False
# 5831    False
# 5943    False
# 5966    False
# 5967    False
# 5968    False
# 5969    False
# 5970    False
# 6080    False
# 6110    False
# 6148    False
# 6197    False
# Name: Injury, dtype: bool

# %%
sns.countplot(data=pds_sharks, y="Injury", palette="crest");

# %%
pds_shark.dropna(subset = ['Injury'], inplace=True)

# %%
pds_shark[pds_shark['Injury'].str.contains('No injury / No attack')]
# Out:
#      Country                 Injury Fatal (Y/N)
# 6110   SPAIN  No injury / No attack         NaN

# %%
pds_shark = pds_shark[~pds_shark['Injury'].str.contains('No injury / No attack')]

# %%
pds_sharks["Injury"] = pds_sharks["Injury"].apply(lambda x: "dead" if x == "FATAL" else "not dead")
pds_sharks
# Out:
# /var/folders/zw/_3ykk0zx0ql2ch8wbzdt6syw0000gn/T/ipykernel_68358/2747535510.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pds_sharks["Injury"] = pds_sharks["Injury"].apply(lambda x: "dead" if x == "FATAL" else "not dead")
#      Country    Injury Fatal (Y/N)
# 82     SPAIN  not dead           N
# 98     SPAIN  not dead         NaN
# 113    SPAIN  not dead           N
# 130    SPAIN  not dead           N
# 234    SPAIN  not dead           N
# 249    SPAIN  not dead           N
# 321    SPAIN  not dead           N
# 378    SPAIN  not dead         NaN
# 471    SPAIN  not dead           N
# 504    SPAIN  not dead           N
# 509    SPAIN  not dead           N
# 529    SPAIN  not dead           N
# 657    SPAIN  not dead         NaN
# ...

# %%
pds_sharks["Injury"].describe()
# Out:
# count           44
# unique           2
# top       not dead
# freq            36
# Name: Injury, dtype: object

# %%
pds_sharks['Injury'].value_counts(normalize=True)
# Out:
# not dead    0.818182
# dead        0.181818
# Name: Injury, dtype: float64

# %%
sns.countplot(data=pds_sharks, y="Injury", palette="crest");

# %%
sns.histplot(x=pds_shark.Injury, bins=20, fill=None, kde=True);# do we want this much detail?
# Out:
# /Users/clarafernandezestela/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/clarafernandezestela/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 147 (\x93) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/clarafernandezestela/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 148 (\x94) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
